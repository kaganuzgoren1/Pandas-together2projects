# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")
df_xlsx= pd.read_excel("pokemon_data.xlsx")

# %%
df_xlsx.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns #headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Name"][:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[1:4]["Name"]
# Out:
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object

# %%
df.iloc[1,1]
# Out:
# 'Ivysaur'

# %%
df.loc[df["Type 1"]=="Grass"] #bütün type 1'i grass olanlar
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df["Type 1"]=="Grass"] #bütün type 1'i grass olanlar
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
for index,row in df.iterrows():
  print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
for index,row in df.iterrows():
  print(index,row)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Attack            50
# Defense          100
# Sp. Atk          100
# Sp. Def          200
# Speed             50
# Generation         3
# Legendary       True
# Name: 415, dtype: object
# 416 #                   379
# Name          Registeel
# Type 1            Steel
# Type 2              NaN
# HP                   80
# Attack               75
# Defense             150
# Sp. Atk              75
# Sp. Def             150
# Speed                50
# Generation            3
# Legendary          True
# Name: 416, dtype: object
# 417 #                 380
# Name           Latias
# Type 1         Dragon
# Type 2        Psychic
# HP                 80
# Attack             80
# Defense            90
# Sp. Atk           110
# Sp. Def           130
# Speed             110
# Generation          3
# Legendary        True
# Name: 417, dtype: object
# 418 #                           380
# Name          LatiasMega Latias
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values("Name")#adları ilkten sona
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values("Attack",ascending=False)#büyükten küçüğe
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1","HP"],ascending=False)# Type 1 baz alınarak HPleri büyükten küçüğe
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321    Wailord  Water     NaN  170      90       45       90       45
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1","HP"],ascending=[1,0])# Type 1 baz alınarak Type 1 isimleri küçükten büyüğe, HPleri büyükten küçüğe
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Filtering Data

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"] == "Poison")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df["Type 1"]=="Grass") | (df["Type 2"] == "Poison")]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"] == "Poison") & (df["HP"]>70)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %%
new_df=df.loc[(df["Type 1"]=="Grass") & (df["Type 2"] == "Poison") & (df["HP"]>70)]
#new_df.to_csv("filtered.csv")
new_df
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %%
#new_df=new_df.reset_index()
new_df=new_df.reset_index(drop=True) #index yazısının columnu da siler
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary
# 0      100     80           1      False
# 1      120     80           1      False
# 2       90     50           1      False
# 3       70     70           1      False
# 4       80     30           5      False

# %%
new_df["Total"]=new_df["HP"]+new_df["Attack"]+new_df["Defense"]+new_df["Speed"]
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0      100     80           1      False    325
# 1      120     80           1      False    383
# 2       90     50           1      False    290
# 3       70     70           1      False    320
# 4       80     30           5      False    299

# %%
new_df["Total_2"]=new_df.iloc[:,4:10].sum(axis=1)
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total  Total_2
# 0      100     80           1      False    325      525
# 1      120     80           1      False    383      625
# 2       90     50           1      False    290      490
# 3       70     70           1      False    320      490
# 4       80     30           5      False    299      464

# %%
new_df.iloc[:,4:10]
# Out:
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   80     105       65      100       70     70
# 4  114      85       70       85       80     30

# %%
new_df=new_df.drop("Total",axis=1)
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total_2
# 0      100     80           1      False      525
# 1      120     80           1      False      625
# 2       90     50           1      False      490
# 3       70     70           1      False      490
# 4       80     30           5      False      464

# %%
new_df=new_df.rename(columns={"Total_2":"Total"})
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0      100     80           1      False    525
# 1      120     80           1      False    625
# 2       90     50           1      False    490
# 3       70     70           1      False    490
# 4       80     30           5      False    464

# %%
cols=list(new_df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
new_df = new_df[cols[0:4]+[cols[-1]]+cols[4:-1]]
new_df
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
df.loc[df["Name"].str.contains("Mega")]#bütün namedeki satırlar içinde Mega olan
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.loc[~df["Name"].str.contains("Mega")]#bütün namedeki satırlar içinde Mega olmayan tilda ile
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
df[["Name","HP"]]# iki column secme
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
df.loc[df["Type 1"].str.contains("Fire|Grass")]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
import re
df.loc[df["Type 1"].str.contains("fire|grass",flags=re.I,regex=True)] #büyük harfleri de alıyo
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df["Name"].str.contains("pi",flags=re.I,regex=True)] #büyük harfleri de alıyo
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 42    37                   Vulpix      Fire       NaN   38      41       40
# 76    70               Weepinbell     Grass    Poison   65      90       50
# 84    78                 Rapidash      Fire       NaN   65     100       70
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
df.loc[df["Name"].str.contains("^pi",flags=re.I,regex=True)] #pi ile başlayanlar
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# # Conditional changes

# %%
df.loc[df["Type 1"]=="Fire","Type 1"]="Flamer"
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df["Type 1"]=="Flamer","Type 1"]="Fire"
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df["Type 1"]=="Flamer","Legendary"]=True
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Total"]=df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.loc[df["Total"] > 500, ["Generation","Legendary"]]="Test Value"
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total
# 0         65       65     45           1       False    318
# ...

# %%
df.loc[df["Total"] > 500, ["Generation","Legendary"]]=["Test Generation","Test Legendary"]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed       Generation       Legendary  Total
# ...

# %% [markdown]
# #Aggregate Statistics (Groupby)

# %%
df = pd.read_csv("pokemon_data.csv")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby(["Type 1"]).mean().sort_values("Defense")
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# ...

# %%
df["Type 1"].value_counts()# hangisinden kaçar tane var
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df.groupby("Type 1").count()# kaçar tane var groupby ile
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df.groupby("Type 1").mean().sort_values("Defense",ascending=True)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# ...

# %%
df.groupby(["Type 1"]).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
df.groupby(["Type 1","Type 2"]).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary
# Type 1 Type 2
# ...

# %%
df.loc[df[ "Type 1"]=="Steel"]
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 223  208                  Steelix  Steel    Ground   75      85      200
# 224  208      SteelixMega Steelix  Steel    Ground   75     125      230
# 245  227                 Skarmory  Steel    Flying   65      80      140
# 328  303                   Mawile  Steel     Fairy   50      85       85
# 329  303        MawileMega Mawile  Steel     Fairy   50     105      125
# 330  304                     Aron  Steel      Rock   50      70      100
# 331  305                   Lairon  Steel      Rock   60      90      140
# 332  306                   Aggron  Steel      Rock   70     110      180
# 333  306        AggronMega Aggron  Steel       NaN   70     140      230
# 410  374                   Beldum  Steel   Psychic   40      55       80
# 411  375                   Metang  Steel   Psychic   60      75      100
# 412  376                Metagross  Steel   Psychic   80     135      130
# ...

# %%
df.loc[2:10,["Type 1","HP"]].sort_values(by="HP")
# Out:
#    Type 1  HP
# 4    Fire  39
# 9   Water  44
# 5    Fire  58
# 10  Water  59
# 6    Fire  78
# 7    Fire  78
# 8    Fire  78
# 2   Grass  80
# 3   Grass  80

# %% [markdown]
# # Large Amount of Data

# %%
new_dff=pd.DataFrame(columns=df.columns)

for df in pd.read_csv("pokemon_data.csv",chunksize=5):
  results=df.groupby(["Name"]).count()
  print(results)
  new_df=pd.concat([new_df,results])
# Out:
#                        #  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1       1       1   1       1        1        1
# Charmander             1       1       0   1       1        1        1
# Ivysaur                1       1       1   1       1        1        1
# Venusaur               1       1       1   1       1        1        1
# VenusaurMega Venusaur  1       1       1   1       1        1        1
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                    1      1           1          1
# Charmander                   1      1           1          1
# Ivysaur                      1      1           1          1
# Venusaur                     1      1           1          1
# VenusaurMega Venusaur        1      1           1          1
#                            #  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Name
# Charizard                  1       1       1   1       1        1        1
# ...

# %%
new_df
# Out:
#                        #                   Name Type 1  Type 2  Total   HP  \
# 0                      3               Venusaur  Grass  Poison  525.0   80
# 1                      3  VenusaurMega Venusaur  Grass  Poison  625.0   80
# 2                     45              Vileplume  Grass  Poison  490.0   75
# 3                     71             Victreebel  Grass  Poison  490.0   80
# 4                    591              Amoonguss  Grass  Poison  464.0  114
# ...                  ...                    ...    ...     ...    ...  ...
# Diancie                1                    NaN      1       1    NaN    1
# DiancieMega Diancie    1                    NaN      1       1    NaN    1
# HoopaHoopa Confined    1                    NaN      1       1    NaN    1
# HoopaHoopa Unbound     1                    NaN      1       1    NaN    1
# Volcanion              1                    NaN      1       1    NaN    1
#
# ...

# %% [markdown]
# # 2nd Project

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/content/Sales_April_2019.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_files = os.listdir("/content")    
csv_files = list(filter(lambda f: f.endswith('.csv'), all_files))
csv_files
# Out:
# ['Sales_March_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv']

# %%
all_months_data=pd.DataFrame()

for file in csv_files:
  df=pd.read_csv("/content/"+file)
  all_months_data=pd.concat([all_months_data,df])
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
all_months_data.to_csv("all_data.csv",index=False)

# %% [markdown]
# #updated df

# %%
all_data=pd.read_csv("all_data.csv")
all_data.head(6)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
# 5   162012       AA Batteries (4-pack)                1       3.84
#
#        Order Date                       Purchase Address
# 0  03/28/19 20:59        942 Church St, Austin, TX 73301
# 1  03/28/19 20:59        942 Church St, Austin, TX 73301
# 2  03/28/19 20:59        942 Church St, Austin, TX 73301
# 3  03/17/19 05:39   261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01   764 13th St, San Francisco, CA 94016
# 5  03/20/19 21:33  187 Ridge St, San Francisco, CA 94016

# %% [markdown]
# # Augment data with additional columns

# %% [markdown]
# #Clean up the data

# %% [markdown]
# # drop row of NaN

# %%
nan_df=all_data[all_data.isna().any(axis=1)]
nan_df.count
# Out:
# <bound method DataFrame.count of        Order ID Product Quantity Ordered Price Each Order Date  \
# 1047        NaN     NaN              NaN        NaN        NaN
# 1542        NaN     NaN              NaN        NaN        NaN
# 1653        NaN     NaN              NaN        NaN        NaN
# 2014        NaN     NaN              NaN        NaN        NaN
# 2043        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185723      NaN     NaN              NaN        NaN        NaN
# 185750      NaN     NaN              NaN        NaN        NaN
# 186271      NaN     NaN              NaN        NaN        NaN
# 186758      NaN     NaN              NaN        NaN        NaN
# 186791      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1047                NaN
# 1542                NaN
# 1653                NaN
# 2014                NaN
# 2043                NaN
# ...                 ...
# ...

# %%
all_data.iloc[312,:]
# Out:
# Order ID                                      162305
# Product                                       iPhone
# Quantity Ordered                                   1
# Price Each                                       700
# Order Date                            03/26/19 17:08
# Purchase Address    460 Hickory St, Dallas, TX 75001
# Name: 312, dtype: object

# %%
all_data=all_data.dropna(how="all") #na drop
all_data.iloc[312,:]
# Out:
# Order ID                                      162305
# Product                                       iPhone
# Quantity Ordered                                   1
# Price Each                                       700
# Order Date                            03/26/19 17:08
# Purchase Address    460 Hickory St, Dallas, TX 75001
# Name: 312, dtype: object

# %%
all_data=all_data.dropna()

# %% [markdown]
# # find "Or" and delete it

# %%
temp_df=all_data[all_data["Order Date"].str[0:2] == "Or"]
temp_df.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 433   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 864   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 930   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1979  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2032  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 433   Purchase Address
# 864   Purchase Address
# 930   Purchase Address
# 1979  Purchase Address
# 2032  Purchase Address

# %%
all_data=all_data[all_data["Order Date"].str[0:2] != "Or"]
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %% [markdown]
# # Converting columns to the correct type pd.to_numeric

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])
big_t=all_data[all_data["Quantity Ordered"]>5]
big_t.sort_values(by=["Quantity Ordered"],ascending=False)
# Out:
#        Order ID                 Product  Quantity Ordered Price Each  \
# 154460   226483  AAA Batteries (4-pack)                 9       2.99
# 155096   227096  AAA Batteries (4-pack)                 9       2.99
# 16462    211097  AAA Batteries (4-pack)                 9       2.99
# 48989    278566  AAA Batteries (4-pack)                 8       2.99
# 62036    291034  AAA Batteries (4-pack)                 8       2.99
# ...         ...                     ...               ...        ...
# 71869    252927  AAA Batteries (4-pack)                 6       2.99
# 66674    295458  AAA Batteries (4-pack)                 6       2.99
# 66632    295417  AAA Batteries (4-pack)                 6       2.99
# 60945    289990   AA Batteries (4-pack)                 6       3.84
# 185916   149609  AAA Batteries (4-pack)                 6       2.99
#
#             Order Date                        Purchase Address
# 154460  07/20/19 23:28  867 Sunset St, San Francisco, CA 94016
# ...

# %%
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %% [markdown]
# # Add a month column

# %%
all_data["Month"]=all_data["Order Date"].str[0:2] #str olarak alır
all_data["Month"]=all_data["Month"].astype("int32")
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Month
# ...

# %% [markdown]
# #Add Sales Column

# %%
all_data["Sales"]=all_data["Quantity Ordered"]*all_data["Price Each"]
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Month   Sales
# ...

# %% [markdown]
# #Add city column

# %%
all_data["Column"]=all_data["Purchase Address"].apply(lambda x: x.split(",")[1])
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Month   Sales  \
# ...

# %%
def get_city(address):
  return address.split(",")[1]
def get_state(address):
  return address.split(",")[2].split(" ")[1]
  
all_data["City"]=all_data["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Month   Sales  \
# ...

# %%
all_data=all_data.drop(columns="Column")
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#             Order Date                      Purchase Address  Month   Sales  \
# ...

# %% [markdown]
# #Question what was the best month for sales ? How much was earned that month?

# %%
results=all_data.groupby("Month").sum()
results
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
all_data.groupby("Month").sum()["Sales"]
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
months=range(1,13)
plt.bar(months,results["Sales"])
plt.xticks(months)
plt.ylabel("Sales in USD ($)")
plt.xlabel("Month Number")
plt.show()

# %% [markdown]
# # Which city has the highest number of sales ?

# %%
resultsc=all_data.groupby("City").sum().sort_values(by="Sales",ascending=False)
resultsc
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Portland (ME)                   2750   447189.25   17144   449758.27

# %%
#cities=all_data["City"].unique()
cities=[city for city, df in all_data.groupby("City")]
plt.bar(cities,resultsc["Sales"])
plt.xticks(cities,rotation="vertical",size=8)
plt.ylabel("Sales in USD ($)")
plt.xlabel("city name")
plt.show()

# %%
for names,df in all_data.groupby("Product"):
  print(names)
# Out:
# 20in Monitor
# 27in 4K Gaming Monitor
# 27in FHD Monitor
# 34in Ultrawide Monitor
# AA Batteries (4-pack)
# AAA Batteries (4-pack)
# Apple Airpods Headphones
# Bose SoundSport Headphones
# Flatscreen TV
# Google Phone
# LG Dryer
# LG Washing Machine
# Lightning Charging Cable
# Macbook Pro Laptop
# ThinkPad Laptop
# USB-C Charging Cable
# Vareebadd Phone
# Wired Headphones
# iPhone

# %% [markdown]
# # What time should we display the advertisments to maximize likelihood of customer's buying product?

# %%
all_data["Order Date"]=pd.to_datetime(all_data["Order Date"])

# %%
all_data["Hour"]=all_data["Order Date"].dt.hour
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#                 Order Date                      Purchase Address  Month  \
# ...

# %%
all_data["Minute"]=all_data["Order Date"].dt.minute
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#                 Order Date                      Purchase Address  Month  \
# ...

# %%
all_data["Year"]=all_data["Order Date"].dt.year
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        162009                      iPhone                 1      700.00
# 1        162009    Lightning Charging Cable                 1       14.95
# 2        162009            Wired Headphones                 2       11.99
# 3        162010  Bose SoundSport Headphones                 1       99.99
# 4        162011      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186845   150497                20in Monitor                 1      109.99
# 186846   150498            27in FHD Monitor                 1      149.99
# 186847   150499             ThinkPad Laptop                 1      999.99
# 186848   150500      AAA Batteries (4-pack)                 2        2.99
# 186849   150501                Google Phone                 1      600.00
#
#                 Order Date                      Purchase Address  Month  \
# ...

# %%
resulth=all_data.groupby("Hour").count()
resulth
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours=[hour for hour,df in all_data.groupby("Hour")]

plt.plot(hours,all_data.groupby("Hour").count())
plt.xticks(hours)
plt.grid()
plt.show()

# %%
resultshour=all_data.groupby("Hour").sum()
#resultshour.index
resultshour.head()
# Out:
#       Quantity Ordered  Price Each  Month      Sales  Minute     Year
# Hour
# 0                 4428   709296.70  27554  713721.27  103596  7894302
# 1                 2619   458490.00  16657  460866.88   61807  4744659
# 2                 1398   233833.64   8507  234851.44   32508  2509621
# 3                  928   144726.42   5904  145757.89   23044  1677792
# 4                  937   162058.18   6148  162661.01   26876  1724230

# %%
plt.plot(resultshour.index,resultshour["Quantity Ordered"])
plt.xticks(resultshour.index,)
plt.grid()
plt.show()

# %% [markdown]
# #What products are most sold together

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3  700.00
# 1 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   14.95
# 2 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   23.98
# 3 2019-03-17 05:39:00  261 10th St, San Francisco, CA 94016      3   99.99
# 4 2019-03-10 00:01:00  764 13th St, San Francisco, CA 94016      3  379.99
#
#                   City  Hour  Minute  Year
# 0          Austin (TX)    20      59  2019
# ...

# %%
df=all_data[all_data["Order ID"].duplicated(keep=False)]
df.head(10)
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    162009                    iPhone                 1      700.00
# 1    162009  Lightning Charging Cable                 1       14.95
# 2    162009          Wired Headphones                 2       11.99
# 30   162037                    iPhone                 1      700.00
# 31   162037  Lightning Charging Cable                 1       14.95
# 60   162066     AA Batteries (4-pack)                 1        3.84
# 61   162066      USB-C Charging Cable                 2       11.95
# 66   162071           Vareebadd Phone                 1      400.00
# 67   162071      USB-C Charging Cable                 1       11.95
# 78   162082           Vareebadd Phone                 1      400.00
#
#             Order Date                        Purchase Address  Month   Sales  \
# 0  2019-03-28 20:59:00         942 Church St, Austin, TX 73301      3  700.00
# ...

# %%
df["Grouped"]=df.groupby("Order ID")["Product"].transform(lambda x: ", ".join(x))
df.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     Order ID                   Product  Quantity Ordered  Price Each  \
# 0     162009                    iPhone                 1      700.00
# 1     162009  Lightning Charging Cable                 1       14.95
# 2     162009          Wired Headphones                 2       11.99
# 30    162037                    iPhone                 1      700.00
# 31    162037  Lightning Charging Cable                 1       14.95
# 60    162066     AA Batteries (4-pack)                 1        3.84
# 61    162066      USB-C Charging Cable                 2       11.95
# ...

# %%
df=df[["Order ID","Grouped"]].drop_duplicates()
df.head()
# Out:
#    Order ID                                            Grouped
# 0    162009  iPhone, Lightning Charging Cable, Wired Headph...
# 30   162037                   iPhone, Lightning Charging Cable
# 60   162066        AA Batteries (4-pack), USB-C Charging Cable
# 66   162071              Vareebadd Phone, USB-C Charging Cable
# 78   162082                  Vareebadd Phone, Wired Headphones

# %%
from itertools import combinations
from collections import Counter
from more_itertools import pairwise

count=Counter()

for row in df["Grouped"]:
  row_list=row.split(",")
  count.update(Counter(combinations(row_list,2)))

print(count)
print(count.most_common(10))
# Out:
# Counter({('iPhone', ' Lightning Charging Cable'): 1005, ('Google Phone', ' USB-C Charging Cable'): 987, ('iPhone', ' Wired Headphones'): 447, ('Google Phone', ' Wired Headphones'): 414, ('Vareebadd Phone', ' USB-C Charging Cable'): 361, ('iPhone', ' Apple Airpods Headphones'): 360, ('Google Phone', ' Bose SoundSport Headphones'): 220, ('Vareebadd Phone', ' Wired Headphones'): 143, (' USB-C Charging Cable', ' Wired Headphones'): 120, ('Vareebadd Phone', ' Bose SoundSport Headphones'): 80, (' Lightning Charging Cable', ' Wired Headphones'): 62, ('Lightning Charging Cable', ' USB-C Charging Cable'): 55, ('Lightning Charging Cable', ' AA Batteries (4-pack)'): 52, (' USB-C Charging Cable', ' Bose SoundSport Headphones'): 51, ('Lightning Charging Cable', ' Lightning Charging Cable'): 51, ('AA Batteries (4-pack)', ' Lightning Charging Cable'): 51, ('AAA Batteries (4-pack)', ' USB-C Charging Cable'): 50, ('AAA Batteries (4-pack)', ' AAA Batteries (4-pack)'): 48, ('AA Batteries (4-pack)', ' A
# ...

# %%
for key,value in count.most_common(10):
  print(key,value)
# Out:
# ('iPhone', ' Lightning Charging Cable') 1005
# ('Google Phone', ' USB-C Charging Cable') 987
# ('iPhone', ' Wired Headphones') 447
# ('Google Phone', ' Wired Headphones') 414
# ('Vareebadd Phone', ' USB-C Charging Cable') 361
# ('iPhone', ' Apple Airpods Headphones') 360
# ('Google Phone', ' Bose SoundSport Headphones') 220
# ('Vareebadd Phone', ' Wired Headphones') 143
# (' USB-C Charging Cable', ' Wired Headphones') 120
# ('Vareebadd Phone', ' Bose SoundSport Headphones') 80

# %%
a=[[1,2],[3,2,1],[3,2],[1,3],[1,2,3,4],[2,3,4]]
b=Counter()
for row in a:
  #print(row)
  b.update(Counter(combinations(row,2)))
print(b)
# Out:
# Counter({(1, 2): 2, (3, 2): 2, (1, 3): 2, (2, 3): 2, (2, 4): 2, (3, 4): 2, (3, 1): 1, (2, 1): 1, (1, 4): 1})

# %%
a=[[1,2],[3,2,1],[3,2],[1,3],[1,2,3,4],[2,3,4]]
b=Counter()
for row in a:
  #print(row)
  b.update(Counter(pairwise(row)))
print(b)
# Out:
# Counter({(1, 2): 2, (3, 2): 2, (2, 3): 2, (3, 4): 2, (2, 1): 1, (1, 3): 1})

# %% [markdown]
# #What prodcut sold the most? Why do you think it sold the most?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3  700.00
# 1 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   14.95
# 2 2019-03-28 20:59:00       942 Church St, Austin, TX 73301      3   23.98
# 3 2019-03-17 05:39:00  261 10th St, San Francisco, CA 94016      3   99.99
# 4 2019-03-10 00:01:00  764 13th St, San Francisco, CA 94016      3  379.99
#
#                   City  Hour  Minute  Year
# 0          Austin (TX)    20      59  2019
# ...

# %%
product_group=all_data.groupby("Product")
quantity_ordered=product_group.sum()["Quantity Ordered"].sort_values(ascending=False)
quantity_ordered
# Out:
# Product
# AAA Batteries (4-pack)        31017
# AA Batteries (4-pack)         27635
# USB-C Charging Cable          23975
# Lightning Charging Cable      23217
# Wired Headphones              20557
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# 27in FHD Monitor               7550
# iPhone                         6849
# 27in 4K Gaming Monitor         6244
# 34in Ultrawide Monitor         6199
# Google Phone                   5532
# Flatscreen TV                  4819
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# 20in Monitor                   4129
# Vareebadd Phone                2068
# LG Washing Machine              666
# LG Dryer                        646
# Name: Quantity Ordered, dtype: int64

# %%
products=[product for product,df in product_group]
products
# Out:
# ['20in Monitor',
#  '27in 4K Gaming Monitor',
#  '27in FHD Monitor',
#  '34in Ultrawide Monitor',
#  'AA Batteries (4-pack)',
#  'AAA Batteries (4-pack)',
#  'Apple Airpods Headphones',
#  'Bose SoundSport Headphones',
#  'Flatscreen TV',
#  'Google Phone',
#  'LG Dryer',
#  'LG Washing Machine',
#  'Lightning Charging Cable',
#  'Macbook Pro Laptop',
#  'ThinkPad Laptop',
#  'USB-C Charging Cable',
#  'Vareebadd Phone',
#  'Wired Headphones',
#  'iPhone']

# %%
plt.bar(products,quantity_ordered)
plt.xticks(products,rotation="vertical",size=8)
plt.ylabel("Quantity Ordered")
plt.xlabel("Product Name")
plt.show()
